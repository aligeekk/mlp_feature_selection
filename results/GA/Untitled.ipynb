# %%
results = {1:  (60.07751937984496 , 52.95607235142119),
2:  (61.24031007751938 , 52.95607235142119),
3:  (57.751937984496124 , 52.614987080103354),
4:  (59.30232558139535 ,  53.36434108527131),
5:  (60.85271317829457 ,  53.17829457364341),
6:  (60.46511627906977 ,  53.286821705426355),
7:  (59.689922480620154 , 53.21447028423773),
8:  (60.07751937984496 ,  53.09560723514212),
9:  (58.91472868217054 ,  52.92506459948321),
10: (60.85271317829457 ,  52.97157622739018),
11: (61.24031007751938 , 53.81912144702842),
12: (60.46511627906977 ,  53.49870801033592),
13: (61.24031007751938 ,  53.6589147286821614),
14: (60.46511627906977 ,  52.95090439276486),
15: (60.85271317829457 , 53.002583979328165),
16: (58.91472868217054 ,  52.80103359173127),
17: (59.689922480620154 ,52.85788113695091),
18: (60.85271317829457 , 53.41085271317829),
19: (59.689922480620154 ,53.78811369509044),
20: (62.7906976744186 , 53.48837209302326),
21: (59.30232558139535 , 52.68217054263566),
22: (61.24031007751938 ,  53.29198966408269),
23: (58.91472868217054 ,  53.17829457364341),
24: (61.24031007751938 , 53.452196382428944),
25: (62.01550387596899 , 53.03359173126615)}

# %%
import matplotlib.pyplot as plt

x = results.keys()
y_best = [item[0] for item in results.values()]
plt.plot(x, y_best, label='Max fitness')
y_average = [item[1] for item in results.values()]
plt.plot(x, y_average, label='Mean fitness')

plt.ylabel("Fitness (test accuracy)")
plt.xlabel("Generation")
plt.title("Fitness by Generation")
plt.legend()
plt.show()
